# 25                -16.49                -1.21                -3.75
# 26                -23.26                -2.29                -5.41
# 27                -21.17                -4.17                -6.88
# 28                -22.31                -1.81                -4.75
# 29                -10.20                -0.11                -2.66
# ..                   ...                  ...                  ...
# 295               -16.13                -0.81                -3.22
# 296               -18.05                -0.34                -2.86
# 297               -23.25                -1.61                -4.22
# 298               -23.26                -1.94                -4.69
# 299               -18.03                -0.73                -3.24
# 300               -16.65                -1.04                -3.47
# 301               -15.62                -2.06                -4.40
# 302               -23.23                -1.18                -3.80
# 303               -18.87                -0.82                -3.42
# 304               -20.12                -0.93                -3.52
# 305               -14.97                -1.38                -3.70
# 306               -18.24                -1.61                -4.43
# 307               -25.95                -1.06                -4.03
# 308               -23.84                -1.93                -4.59
# 309               -13.05                -1.88                -4.00
# 310               -23.86                -1.18                -3.92
# 311               -25.06                -3.09                -5.59
# 312               -18.03                -1.29                -3.92
# 313               -23.06                -1.53                -4.15
# 314               -15.46                -1.28                -3.68
# 315               -17.18                -1.53                -3.71
# 316               -16.59                -1.25                -3.73
# 317               -22.81                -1.47                -4.06
# 318               -27.16                -2.84                -5.10
# 319               -25.30                -2.66                -5.12
# 320               -22.85                -1.49                -4.10
# 321               -11.13                -1.48                -3.55
# 322               -24.50                -2.53                -4.97
# 323               -24.39                -2.21                -4.72
# 324               -12.74                -1.36                -3.63
#
# [325 rows x 28 columns]

# %%
data.head()
# Out:
#   class  b1  b2  b3   b4  b5   b6   b7  b8  b9  ...  pred_minus_obs_H_b9  \
# 0    d   67  51  68  115  69  111  136  31  67  ...                -9.17
# 1    s   67  28  51   99  50   97   82  26  59  ...                -2.25
# 2    s   63  26  50   95  49   91   81  26  57  ...                -0.44
# 3    d   63  42  63   97  66  108  111  28  59  ...                -2.34
# 4    s   46  27  50   83  51   90   76  26  56  ...                 1.25
#
#    pred_minus_obs_S_b1  pred_minus_obs_S_b2  pred_minus_obs_S_b3  \
# 0               -18.27                -1.80                -6.32
# 1               -20.13                -2.11                -6.35
# 2               -17.64                -1.81                -4.70
# 3               -20.20                -1.89                -5.47
# 4               -18.62                -2.17                -7.11
#
#    pred_minus_obs_S_b4  pred_minus_obs_S_b5  pred_minus_obs_S_b6  \
# 0               -20.88                -1.63                -6.13
# 1               -21.94                -1.22                -6.13
# 2               -19.39                -0.65                -5.01
# 3               -21.65                -0.99                -5.71
# 4               -21.12                -1.56                -6.35
#
#    pred_minus_obs_S_b7  pred_minus_obs_S_b8  pred_minus_obs_S_b9
# 0               -22.56                -5.53                -8.11
# 1               -22.20                -3.41                -6.57
# 2               -20.89                -3.96                -6.85
# 3               -22.19                -3.41                -6.52
# 4               -22.19                -4.45                -7.32
#
# [5 rows x 28 columns]

# %%
data.tail()
# Out:
#     class  b1  b2  b3   b4  b5   b6  b7  b8  b9  ...  pred_minus_obs_H_b9  \
# 320    o   55  56  72   91  79  113  86  35  68  ...               -12.86
# 321    d   69  49  76   91  52   91  92  25  57  ...                -2.36
# 322    s   49  26  48  107  59  104  62  22  53  ...                 2.32
# 323    s   55  26  52   92  55   98  65  23  56  ...                -0.77
# 324    h   71  28  51   96  46   88  92  25  58  ...                -3.24
#
#      pred_minus_obs_S_b1  pred_minus_obs_S_b2  pred_minus_obs_S_b3  \
# 320               -23.08                -0.08                -3.46
# 321               -11.47                -0.40                -3.74
# 322               -23.48                 1.44                -1.59
# 323               -23.74                 1.27                -1.30
# 324               -13.96                -0.44                -3.84
#
#      pred_minus_obs_S_b4  pred_minus_obs_S_b5  pred_minus_obs_S_b6  \
# 320               -27.52                -1.04                -4.73
# 321               -16.90                -0.78                -4.15
# 322               -26.98                -1.36                -4.81
# 323               -25.53                -1.21                -4.70
# 324               -15.45                -0.71                -3.94
#
#      pred_minus_obs_S_b7  pred_minus_obs_S_b8  pred_minus_obs_S_b9
# 320               -22.85                -1.49                -4.10
# 321               -11.13                -1.48                -3.55
# 322               -24.50                -2.53                -4.97
# 323               -24.39                -2.21                -4.72
# 324               -12.74                -1.36                -3.63
#
# [5 rows x 28 columns]

# %%
data.shape
# Out:
# (325, 28)

# %%
data.columns
# Out:
# Index(['class', 'b1', 'b2', 'b3', 'b4', 'b5', 'b6', 'b7', 'b8', 'b9',
#        'pred_minus_obs_H_b1', 'pred_minus_obs_H_b2', 'pred_minus_obs_H_b3',
#        'pred_minus_obs_H_b4', 'pred_minus_obs_H_b5', 'pred_minus_obs_H_b6',
#        'pred_minus_obs_H_b7', 'pred_minus_obs_H_b8', 'pred_minus_obs_H_b9',
#        'pred_minus_obs_S_b1', 'pred_minus_obs_S_b2', 'pred_minus_obs_S_b3',
#        'pred_minus_obs_S_b4', 'pred_minus_obs_S_b5', 'pred_minus_obs_S_b6',
#        'pred_minus_obs_S_b7', 'pred_minus_obs_S_b8', 'pred_minus_obs_S_b9'],
#       dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=325, step=1)

# %%
data.at[2, 'b2']
# Out:
# 26

# %%
data['class']
# Out:
# 0      d
# 1      s
# 2      s
# 3      d
# 4      s
# 5      d
# 6      h
# 7      o
# 8      s
# 9      d
# 10     s
# 11     o
# 12     d
# 13     s
# 14     o
# 15     s
# 16     o
# 17     d
# 18     s
# 19     o
# 20     o
# 21     d
# 22     d
# 23     s
# 24     s
# 25     s
# 26     d
# 27     d
# 28     s
# 29     d
#        ..
# 295    s
# 296    s
# 297    s
# 298    s
# 299    d
# 300    s
# 301    s
# 302    h
# 303    h
# 304    d
# 305    s
# 306    d
# 307    s
# 308    h
# 309    h
# 310    o
# 311    s
# 312    s
# 313    h
# 314    s
# 315    h
# 316    s
# 317    h
# 318    s
# 319    o
# 320    o
# 321    d
# 322    s
# 323    s
# 324    h
# Name: class, Length: 325, dtype: object

# %%
data[['class', 'b3', 'b5']].head()
# Out:
#   class  b3  b5
# 0    d   68  69
# 1    s   51  50
# 2    s   50  49
# 3    d   63  66
# 4    s   50  51

# %%
data.describe()
# Out:
#                b1          b2          b3          b4          b5          b6  \
# count  325.000000  325.000000  325.000000  325.000000  325.000000  325.000000
# mean    58.021538   38.381538   61.467692   96.175385   58.098462   99.196923
# std     11.705076   14.589516   15.003385   11.120136   10.654920    9.438789
# min     31.000000   23.000000   47.000000   69.000000   43.000000   83.000000
# 25%     50.000000   28.000000   52.000000   89.000000   51.000000   93.000000
# 50%     57.000000   32.000000   55.000000   95.000000   54.000000   96.000000
# 75%     65.000000   43.000000   65.000000  103.000000   63.000000  103.000000
# max    107.000000   91.000000  124.000000  141.000000  100.000000  138.000000
#
#                b7          b8          b9  pred_minus_obs_H_b1  ...  \
# count  325.000000  325.000000  325.000000           325.000000  ...
# mean    85.864615   27.375385   58.880000            55.786769  ...
# std     16.642765    7.445316    8.884777            12.347445  ...
# min     42.000000   19.000000   45.000000             4.950000  ...
# 25%     73.000000   24.000000   54.000000            48.370000  ...
# 50%     85.000000   25.000000   57.000000            57.560000  ...
# 75%     98.000000   27.000000   60.000000            64.120000  ...
# max    136.000000   84.000000  114.000000            86.080000  ...
#
#        pred_minus_obs_H_b9  pred_minus_obs_S_b1  pred_minus_obs_S_b2  \
# count           325.000000           325.000000           325.000000
# mean             -3.341446           -20.004954            -1.086092
# std               8.921301             2.908311             1.054544
# min             -58.280000           -26.790000            -5.510000
# 25%              -4.660000           -22.250000            -1.750000
# 50%              -1.250000           -19.950000            -1.030000
# 75%               1.430000           -18.250000            -0.390000
# max               9.580000            -7.760000             1.780000
#
#        pred_minus_obs_S_b3  pred_minus_obs_S_b4  pred_minus_obs_S_b5  \
# count           325.000000           325.000000           325.000000
# mean             -4.375846           -21.664185            -0.979815
# std               1.850954             3.594512             0.308081
# min             -10.120000           -34.630000            -1.830000
# 25%              -5.530000           -24.220000            -1.190000
# 50%              -4.490000           -21.040000            -0.990000
# 75%              -2.770000           -19.060000            -0.780000
# max               1.040000           -12.070000             0.260000
#
#        pred_minus_obs_S_b6  pred_minus_obs_S_b7  pred_minus_obs_S_b8  \
# count           325.000000           325.000000           325.000000
# mean             -4.633323           -18.996462            -1.701785
# std               1.054033             3.307265             1.017594
# min              -7.970000           -29.340000            -6.500000
# 25%              -5.410000           -21.780000            -2.360000
# 50%              -4.670000           -18.870000            -1.650000
# 75%              -3.900000           -16.770000            -1.030000
# max              -0.770000            -8.330000             2.580000
#
#        pred_minus_obs_S_b9
# count           325.000000
# mean             -4.229108
# std               1.150070
# min              -8.930000
# 25%              -4.870000
# 50%              -4.150000
# 75%              -3.290000
# max              -0.590000
#
# [8 rows x 27 columns]

# %%
data.corr()
# Out:
#                            b1        b2        b3        b4        b5  \
# b1                   1.000000  0.193934  0.239083  0.659619  0.064797
# b2                   0.193934  1.000000  0.973858  0.007348  0.856469
# b3                   0.239083  0.973858  1.000000 -0.000216  0.811359
# b4                   0.659619  0.007348 -0.000216  1.000000 -0.005669
# b5                   0.064797  0.856469  0.811359 -0.005669  1.000000
# b6                   0.125729  0.742261  0.696819  0.239442  0.916407
# b7                   0.538652  0.371865  0.302484  0.523521  0.345639
# b8                   0.221787  0.693000  0.687960  0.043042  0.773810
# b9                   0.373938  0.639570  0.633026  0.206517  0.721207
# pred_minus_obs_H_b1 -0.969862 -0.230664 -0.277980 -0.581170 -0.061491
# pred_minus_obs_H_b2 -0.204415 -0.992976 -0.971490  0.016287 -0.825342
# pred_minus_obs_H_b3 -0.251750 -0.951036 -0.982061  0.043267 -0.753583
# pred_minus_obs_H_b4 -0.665051 -0.072310 -0.067227 -0.952572 -0.032222
# pred_minus_obs_H_b5 -0.066440 -0.860788 -0.816948  0.011241 -0.998861
# pred_minus_obs_H_b6 -0.131404 -0.764436 -0.722988 -0.219004 -0.919803
# pred_minus_obs_H_b7 -0.534366 -0.389844 -0.321659 -0.501946 -0.345772
# pred_minus_obs_S_b6             0.625112             0.526984
# pred_minus_obs_S_b7             1.000000             0.465048
# pred_minus_obs_S_b8             0.465048             1.000000
# pred_minus_obs_S_b9             0.604831             0.947183
#
#                      pred_minus_obs_S_b9
# b1                              0.042786
# b2                              0.098965
# b3                              0.108672
# b4                             -0.093573
# b5                              0.013418
# b6                             -0.010124
# b7                             -0.050133
# b8                              0.095001
# b9                              0.075192
# pred_minus_obs_H_b1            -0.153285
# pred_minus_obs_H_b2            -0.143493
# pred_minus_obs_H_b3            -0.184396
# pred_minus_obs_H_b4            -0.104644
# pred_minus_obs_H_b5            -0.034589
# pred_minus_obs_H_b6            -0.071782
# pred_minus_obs_H_b7            -0.051608
# pred_minus_obs_H_b8            -0.156825
# pred_minus_obs_H_b9            -0.150596
# pred_minus_obs_S_b1             0.296599
# pred_minus_obs_S_b2             0.565025
# pred_minus_obs_S_b3             0.580176
# pred_minus_obs_S_b4             0.441255
# pred_minus_obs_S_b5             0.501219
# pred_minus_obs_S_b6             0.644272
# pred_minus_obs_S_b7             0.604831
# pred_minus_obs_S_b8             0.947183
# pred_minus_obs_S_b9             1.000000
#
# [27 rows x 27 columns]

# %%
pd.plotting.scatter_matrix(data[['class', 'b1', 'b2', 'pred_minus_obs_H_b1', 'pred_minus_obs_H_b2', 'pred_minus_obs_S_b1', 'pred_minus_obs_S_b2']], alpha=.01, figsize=(10, 10))
pass

# %%
pd.plotting.scatter_matrix(data[['b1', 'b2', 'pred_minus_obs_H_b1', 'pred_minus_obs_H_b2', 'pred_minus_obs_S_b1', 'pred_minus_obs_S_b2']], figsize=(10, 10))
pass

# %%
plt.plot(data['b1'], data['pred_minus_obs_H_b1'], 'o')
plt.xlabel('b1 ASTER image band')
plt.ylabel('Predicted spectral values (based on spatial interpolation) minus actual spectral values for the H class')
plt.title('Test')
pass

# %%
data['b1'] < 63
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
# 5       True
# 6      False
# 7      False
# 8      False
# 9       True
# 10     False
# 11      True
# 12      True
# 13     False
# 14      True
# 15      True
# 16      True
# 17      True
# 18      True
# 19      True
# 20     False
# 21      True
# 22      True
# 23     False
# 24      True
# 25      True
# 26     False
# 27      True
# 28      True
# 29      True
#        ...
# 295    False
# 296    False
# 297     True
# 298     True
# 299     True
# 300    False
# 301     True
# 302    False
# 303    False
# 304     True
# 305     True
# 306    False
# 307     True
# 308    False
# 309    False
# 310     True
# 311     True
# 312    False
# 313    False
# 314     True
# 315    False
# 316     True
# 317    False
# 318     True
# 319     True
# 320     True
# 321    False
# 322     True
# 323     True
# 324    False
# Name: b1, Length: 325, dtype: bool

# %%
np.random.seed(0)
b1_rnd = data['b1'] + np.random.rand(data.shape[0]) - .5

plt.figure(figsize = (20, 8))

plt.scatter(b1_rnd[data['b2'] >= 60],
            data[data['b2'] >= 60]['pred_minus_obs_H_b2'],
            label = '>= 60',
            color = 'b')

plt.scatter(b1_rnd[data['b2'] < 60],
            data[data['b2'] < 60]['pred_minus_obs_H_b2'],
            label = '< 60',
            color = 'r')

plt.xlabel('b1')
plt.xticks(range(100))
plt.xlim(0, 100)
plt.ylabel('b2')
plt.title('Test2')
plt.grid()

# %%
data.describe(include = ['object'])
# Out:
#        class
# count    325
# unique     4
# top       s
# freq     136

# %%
data.describe(include = 'all')
# Out:
#        class          b1          b2          b3          b4          b5  \
# count    325  325.000000  325.000000  325.000000  325.000000  325.000000
# unique     4         NaN         NaN         NaN         NaN         NaN
# top       s          NaN         NaN         NaN         NaN         NaN
# freq     136         NaN         NaN         NaN         NaN         NaN
# mean     NaN   58.021538   38.381538   61.467692   96.175385   58.098462
# std      NaN   11.705076   14.589516   15.003385   11.120136   10.654920
# min      NaN   31.000000   23.000000   47.000000   69.000000   43.000000
# 25%      NaN   50.000000   28.000000   52.000000   89.000000   51.000000
# 50%      NaN   57.000000   32.000000   55.000000   95.000000   54.000000
# 75%      NaN   65.000000   43.000000   65.000000  103.000000   63.000000
# max      NaN  107.000000   91.000000  124.000000  141.000000  100.000000
#
#                 b6          b7          b8          b9  ...  \
# count   325.000000  325.000000  325.000000  325.000000  ...
# unique         NaN         NaN         NaN         NaN  ...
# top            NaN         NaN         NaN         NaN  ...
# freq           NaN         NaN         NaN         NaN  ...
# mean     99.196923   85.864615   27.375385   58.880000  ...
# std       9.438789   16.642765    7.445316    8.884777  ...
# min      83.000000   42.000000   19.000000   45.000000  ...
# 25%      93.000000   73.000000   24.000000   54.000000  ...
# 50%      96.000000   85.000000   25.000000   57.000000  ...
# 75%     103.000000   98.000000   27.000000   60.000000  ...
# max     138.000000  136.000000   84.000000  114.000000  ...
#
#         pred_minus_obs_H_b9  pred_minus_obs_S_b1  pred_minus_obs_S_b2  \
# count            325.000000           325.000000           325.000000
# unique                  NaN                  NaN                  NaN
# top                     NaN                  NaN                  NaN
# freq                    NaN                  NaN                  NaN
# mean              -3.341446           -20.004954            -1.086092
# std                8.921301             2.908311             1.054544
# min              -58.280000           -26.790000            -5.510000
# 25%               -4.660000           -22.250000            -1.750000
# 50%               -1.250000           -19.950000            -1.030000
# 75%                1.430000           -18.250000            -0.390000
# max                9.580000            -7.760000             1.780000
#
#         pred_minus_obs_S_b3  pred_minus_obs_S_b4  pred_minus_obs_S_b5  \
# count            325.000000           325.000000           325.000000
# unique                  NaN                  NaN                  NaN
# top                     NaN                  NaN                  NaN
# freq                    NaN                  NaN                  NaN
# mean              -4.375846           -21.664185            -0.979815
# std                1.850954             3.594512             0.308081
# min              -10.120000           -34.630000            -1.830000
# 25%               -5.530000           -24.220000            -1.190000
# 50%               -4.490000           -21.040000            -0.990000
# 75%               -2.770000           -19.060000            -0.780000
# max                1.040000           -12.070000             0.260000
#
#         pred_minus_obs_S_b6  pred_minus_obs_S_b7  pred_minus_obs_S_b8  \
# count            325.000000           325.000000           325.000000
# unique                  NaN                  NaN                  NaN
# top                     NaN                  NaN                  NaN
# freq                    NaN                  NaN                  NaN
# mean              -4.633323           -18.996462            -1.701785
# std                1.054033             3.307265             1.017594
# min               -7.970000           -29.340000            -6.500000
# 25%               -5.410000           -21.780000            -2.360000
# 50%               -4.670000           -18.870000            -1.650000
# 75%               -3.900000           -16.770000            -1.030000
# max               -0.770000            -8.330000             2.580000
#
#         pred_minus_obs_S_b9
# count            325.000000
# unique                  NaN
# top                     NaN
# freq                    NaN
# mean              -4.229108
# std                1.150070
# min               -8.930000
# 25%               -4.870000
# 50%               -4.150000
# 75%               -3.290000
# max               -0.590000
#
# [11 rows x 28 columns]

# %%
data['class'].unique()
# Out:
# array(['d ', 's ', 'h ', 'o '], dtype=object)

# %%
data['b1'].unique()
# Out:
# array([ 67,  63,  46,  59,  83,  77,  57,  65,  53,  45,  81,  58,  50,
#         36,  56,  40,  75,  31,  47,  48,  68,  55,  49,  60,  54,  62,
#         64,  42,  73,  43,  76,  70,  78,  52,  79,  61,  71,  66,  44,
#         74,  69,  51,  85,  80,  72,  35,  39, 107,  32,  34,  33,  90,
#         41,  37,  38,  82,  84], dtype=int64)

# %%
categorical_columns = [c for c in data.columns if data[c].dtype.name == 'object']
numerical_columns   = [c for c in data.columns if data[c].dtype.name != 'object']
print(categorical_columns)
print(numerical_columns)
# Out:
# ['class']
# ['b1', 'b2', 'b3', 'b4', 'b5', 'b6', 'b7', 'b8', 'b9', 'pred_minus_obs_H_b1', 'pred_minus_obs_H_b2', 'pred_minus_obs_H_b3', 'pred_minus_obs_H_b4', 'pred_minus_obs_H_b5', 'pred_minus_obs_H_b6', 'pred_minus_obs_H_b7', 'pred_minus_obs_H_b8', 'pred_minus_obs_H_b9', 'pred_minus_obs_S_b1', 'pred_minus_obs_S_b2', 'pred_minus_obs_S_b3', 'pred_minus_obs_S_b4', 'pred_minus_obs_S_b5', 'pred_minus_obs_S_b6', 'pred_minus_obs_S_b7', 'pred_minus_obs_S_b8', 'pred_minus_obs_S_b9']

# %%
for c in categorical_columns:
    print(c, data[c].unique())
# Out:
# class ['d ' 's ' 'h ' 'o ']

# %%
data.median(axis = 0)
# Out:
# b1                     57.00
# b2                     32.00
# b3                     55.00
# b4                     95.00
# b5                     54.00
# b6                     96.00
# b7                     85.00
# b8                     25.00
# b9                     57.00
# pred_minus_obs_H_b1    57.56
# pred_minus_obs_H_b2    18.87
# pred_minus_obs_H_b3    40.88
# pred_minus_obs_H_b4     4.08
# pred_minus_obs_H_b5   -28.90
# pred_minus_obs_H_b6   -36.33
# pred_minus_obs_H_b7    -8.62
# pred_minus_obs_H_b8     4.44
# pred_minus_obs_H_b9    -1.25
# pred_minus_obs_S_b1   -19.95
# pred_minus_obs_S_b2    -1.03
# pred_minus_obs_S_b3    -4.49
# pred_minus_obs_S_b4   -21.04
# pred_minus_obs_S_b5    -0.99
# pred_minus_obs_S_b6    -4.67
# pred_minus_obs_S_b7   -18.87
# pred_minus_obs_S_b8    -1.65
# pred_minus_obs_S_b9    -4.15
# dtype: float64

# %%
data = data.fillna(data.median(axis = 0), axis = 0)

# %%
data_describe = data.describe(include = [object])
for c in categorical_columns:
    data[c] = data[c].fillna(data_describe[c]['top'])

# %%
binary_columns    = [c for c in categorical_columns if data_describe[c]['unique'] == 2]
nonbinary_columns = [c for c in categorical_columns if data_describe[c]['unique'] > 2]
print(binary_columns, nonbinary_columns)
# Out:
# [] ['class']

# %%
data_nonbinary = pd.get_dummies(data[nonbinary_columns])
print(data_nonbinary.columns)
# Out:
# Index(['class_d ', 'class_h ', 'class_o ', 'class_s '], dtype='object')

# %%
data_numerical = data[numerical_columns]
data_numerical.describe()
# Out:
#                b1          b2          b3          b4          b5          b6  \
# count  325.000000  325.000000  325.000000  325.000000  325.000000  325.000000
# mean    58.021538   38.381538   61.467692   96.175385   58.098462   99.196923
# std     11.705076   14.589516   15.003385   11.120136   10.654920    9.438789
# min     31.000000   23.000000   47.000000   69.000000   43.000000   83.000000
# 25%     50.000000   28.000000   52.000000   89.000000   51.000000   93.000000
# 50%     57.000000   32.000000   55.000000   95.000000   54.000000   96.000000
# 75%     65.000000   43.000000   65.000000  103.000000   63.000000  103.000000
# max    107.000000   91.000000  124.000000  141.000000  100.000000  138.000000
#
#                b7          b8          b9  pred_minus_obs_H_b1  ...  \
# count  325.000000  325.000000  325.000000           325.000000  ...
# mean    85.864615   27.375385   58.880000            55.786769  ...
# std     16.642765    7.445316    8.884777            12.347445  ...
# min     42.000000   19.000000   45.000000             4.950000  ...
# 25%     73.000000   24.000000   54.000000            48.370000  ...
# 50%     85.000000   25.000000   57.000000            57.560000  ...
# 75%     98.000000   27.000000   60.000000            64.120000  ...
# max    136.000000   84.000000  114.000000            86.080000  ...
#
#        pred_minus_obs_H_b9  pred_minus_obs_S_b1  pred_minus_obs_S_b2  \
# count           325.000000           325.000000           325.000000
# mean             -3.341446           -20.004954            -1.086092
# std               8.921301             2.908311             1.054544
# min             -58.280000           -26.790000            -5.510000
# 25%              -4.660000           -22.250000            -1.750000
# 50%              -1.250000           -19.950000            -1.030000
# 75%               1.430000           -18.250000            -0.390000
# max               9.580000            -7.760000             1.780000
#
#        pred_minus_obs_S_b3  pred_minus_obs_S_b4  pred_minus_obs_S_b5  \
# count           325.000000           325.000000           325.000000
# mean             -4.375846           -21.664185            -0.979815
# std               1.850954             3.594512             0.308081
# min             -10.120000           -34.630000            -1.830000
# 25%              -5.530000           -24.220000            -1.190000
# 50%              -4.490000           -21.040000            -0.990000
# 75%              -2.770000           -19.060000            -0.780000
# max               1.040000           -12.070000             0.260000
#
#        pred_minus_obs_S_b6  pred_minus_obs_S_b7  pred_minus_obs_S_b8  \
# count           325.000000           325.000000           325.000000
# mean             -4.633323           -18.996462            -1.701785
# std               1.054033             3.307265             1.017594
# min              -7.970000           -29.340000            -6.500000
# 25%              -5.410000           -21.780000            -2.360000
# 50%              -4.670000           -18.870000            -1.650000
# 75%              -3.900000           -16.770000            -1.030000
# max              -0.770000            -8.330000             2.580000
#
#        pred_minus_obs_S_b9
# count           325.000000
# mean             -4.229108
# std               1.150070
# min              -8.930000
# 25%              -4.870000
# 50%              -4.150000
# 75%              -3.290000
# max              -0.590000
#
# [8 rows x 27 columns]

# %%
data_numerical = (data_numerical - data_numerical.mean(axis = 0))/data_numerical.std(axis = 0)

# %%
data_numerical.describe()
# Out:
#                  b1            b2            b3            b4            b5  \
# count  3.250000e+02  3.250000e+02  3.250000e+02  3.250000e+02  3.250000e+02
# mean  -5.465713e-17  6.217249e-17 -1.629466e-16 -1.234056e-17  2.097467e-16
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -2.308532e+00 -1.054287e+00 -9.642952e-01 -2.443800e+00 -1.417041e+00
# 25%   -6.853043e-01 -7.115752e-01 -6.310371e-01 -6.452605e-01 -6.662145e-01
# 50%   -8.727312e-02 -4.374058e-01 -4.310822e-01 -1.056988e-01 -3.846544e-01
# 75%    5.961911e-01  3.165603e-01  2.354340e-01  6.137169e-01  4.600258e-01
# max    4.184378e+00  3.606594e+00  4.167880e+00  4.030941e+00  3.932600e+00
#
#                  b6            b7            b8            b9  \
# count  3.250000e+02  3.250000e+02  3.250000e+02  3.250000e+02
# mean   6.415381e-16 -4.159066e-16  2.215322e-16 -3.111614e-16
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.715996e+00 -2.635657e+00 -1.124920e+00 -1.562223e+00
# 25%   -6.565380e-01 -7.729855e-01 -4.533568e-01 -5.492541e-01
# 50%   -3.387006e-01 -5.195143e-02 -3.190442e-01 -2.115979e-01
# 75%    4.029200e-01  7.291688e-01 -5.041890e-02  1.260583e-01
# max    4.111023e+00  3.012443e+00  7.605402e+00  6.203870e+00
#
#        pred_minus_obs_H_b1  ...  pred_minus_obs_H_b9  pred_minus_obs_S_b1  \
# count         3.250000e+02  ...         3.250000e+02         3.250000e+02
# mean         -1.776357e-15  ...         6.290908e-17         4.973799e-15
# std           1.000000e+00  ...         1.000000e+00         1.000000e+00
# min          -4.117189e+00  ...        -6.158133e+00        -2.332985e+00
# 25%          -6.006724e-01  ...        -1.477984e-01        -7.719417e-01
# 50%           1.436112e-01  ...         2.344329e-01         1.889545e-02
# 75%           6.748952e-01  ...         5.348375e-01         6.034273e-01
# max           2.453401e+00  ...         1.448381e+00         4.210332e+00
#
#        pred_minus_obs_S_b2  pred_minus_obs_S_b3  pred_minus_obs_S_b4  \
# count         3.250000e+02         3.250000e+02         3.250000e+02
# mean         -7.088347e-16        -3.475169e-15         4.393750e-15
# std           1.000000e+00         1.000000e+00         1.000000e+00
# min          -4.195089e+00        -3.103348e+00        -3.607114e+00
# 25%          -6.295682e-01        -6.235455e-01        -7.110325e-01
# 50%           5.319103e-02        -6.167299e-02         1.736493e-01
# 75%           6.600882e-01         8.675777e-01         7.244890e-01
# max           2.717849e+00         2.925976e+00         2.669120e+00
#
#        pred_minus_obs_S_b5  pred_minus_obs_S_b6  pred_minus_obs_S_b7  \
# count         3.250000e+02         3.250000e+02         3.250000e+02
# mean          1.621267e-15         3.127071e-15         5.943963e-17
# std           1.000000e+00         1.000000e+00         1.000000e+00
# min          -2.759610e+00        -3.165629e+00        -3.127521e+00
# 25%          -6.822372e-01        -7.368622e-01        -8.416437e-01
# 50%          -3.305819e-02        -3.479676e-02         3.823750e-02
# 75%           6.485798e-01         6.957308e-01         6.732033e-01
# max           4.024311e+00         3.665278e+00         3.225161e+00
#
#        pred_minus_obs_S_b8  pred_minus_obs_S_b9
# count         3.250000e+02         3.250000e+02
# mean         -1.188793e-15         3.044402e-15
# std           1.000000e+00         1.000000e+00
# min          -4.715257e+00        -4.087484e+00
# 25%          -6.468352e-01        -5.572638e-01
# 50%           5.088929e-02         6.878512e-02
# 75%           6.601698e-01         8.165658e-01
# max           4.207755e+00         3.164249e+00
#
# [8 rows x 27 columns]

# %%
data = pd.concat((data_numerical, data_nonbinary, data[binary_columns]), axis = 1)
print(data.shape)
# Out:
# (325, 31)

# %%
data.describe()
# Out:
#                  b1            b2            b3            b4            b5  \
# count  3.250000e+02  3.250000e+02  3.250000e+02  3.250000e+02  3.250000e+02
# mean  -5.465713e-17  6.217249e-17 -1.629466e-16 -1.234056e-17  2.097467e-16
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -2.308532e+00 -1.054287e+00 -9.642952e-01 -2.443800e+00 -1.417041e+00
# 25%   -6.853043e-01 -7.115752e-01 -6.310371e-01 -6.452605e-01 -6.662145e-01
# 50%   -8.727312e-02 -4.374058e-01 -4.310822e-01 -1.056988e-01 -3.846544e-01
# 75%    5.961911e-01  3.165603e-01  2.354340e-01  6.137169e-01  4.600258e-01
# max    4.184378e+00  3.606594e+00  4.167880e+00  4.030941e+00  3.932600e+00
#
#                  b6            b7            b8            b9  \
# count  3.250000e+02  3.250000e+02  3.250000e+02  3.250000e+02
# mean   6.415381e-16 -4.159066e-16  2.215322e-16 -3.111614e-16
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.715996e+00 -2.635657e+00 -1.124920e+00 -1.562223e+00
# 25%   -6.565380e-01 -7.729855e-01 -4.533568e-01 -5.492541e-01
# 50%   -3.387006e-01 -5.195143e-02 -3.190442e-01 -2.115979e-01
# 75%    4.029200e-01  7.291688e-01 -5.041890e-02  1.260583e-01
# max    4.111023e+00  3.012443e+00  7.605402e+00  6.203870e+00
#
#        pred_minus_obs_H_b1  ...  pred_minus_obs_S_b4  pred_minus_obs_S_b5  \
# count         3.250000e+02  ...         3.250000e+02         3.250000e+02
# mean         -1.776357e-15  ...         4.393750e-15         1.621267e-15
# std           1.000000e+00  ...         1.000000e+00         1.000000e+00
# min          -4.117189e+00  ...        -3.607114e+00        -2.759610e+00
# 25%          -6.006724e-01  ...        -7.110325e-01        -6.822372e-01
# 50%           1.436112e-01  ...         1.736493e-01        -3.305819e-02
# 75%           6.748952e-01  ...         7.244890e-01         6.485798e-01
# max           2.453401e+00  ...         2.669120e+00         4.024311e+00
#
#        pred_minus_obs_S_b6  pred_minus_obs_S_b7  pred_minus_obs_S_b8  \
# count         3.250000e+02         3.250000e+02         3.250000e+02
# mean          3.127071e-15         5.943963e-17        -1.188793e-15
# std           1.000000e+00         1.000000e+00         1.000000e+00
# min          -3.165629e+00        -3.127521e+00        -4.715257e+00
# 25%          -7.368622e-01        -8.416437e-01        -6.468352e-01
# 50%          -3.479676e-02         3.823750e-02         5.088929e-02
# 75%           6.957308e-01         6.732033e-01         6.601698e-01
# max           3.665278e+00         3.225161e+00         4.207755e+00
#
#        pred_minus_obs_S_b9    class_d     class_h     class_o     class_s
# count         3.250000e+02  325.000000  325.000000  325.000000  325.000000
# mean          3.044402e-15    0.323077    0.116923    0.141538    0.418462
# std           1.000000e+00    0.468373    0.321824    0.349114    0.494067
# min          -4.087484e+00    0.000000    0.000000    0.000000    0.000000
# 25%          -5.572638e-01    0.000000    0.000000    0.000000    0.000000
# 50%           6.878512e-02    0.000000    0.000000    0.000000    0.000000
# 75%           8.165658e-01    1.000000    0.000000    0.000000    1.000000
# max           3.164249e+00    1.000000    1.000000    1.000000    1.000000
#
# [8 rows x 31 columns]

# %%
X = data.drop(('b1'), axis = 1)
y = data['b1']
feature_names = X.columns

# %%
print(X.shape)
print(y.shape)
N, d = X.shape
# Out:
# (325, 30)
# (325,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

N_train, _ = X_train.shape 
N_test,  _ = X_test.shape 

print(N_train, N_test)
# Out:
# 227 98

# %%
from sklearn import utils

print(utils.multiclass.type_of_target(y_train))
print(utils.multiclass.type_of_target(y_train.astype('int')))
# Out:
# continuous
# multiclass

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors = 5)
#knn.set_params(n_neighbors=10)
knn.fit(X_train, y_train.astype('int'))
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
y_train_predict = knn.predict(X_train)
y_test_predict = knn.predict(X_test)

err_train = np.mean(y_train.astype('int') != y_train_predict)
err_test  = np.mean(y_test.astype('int')  != y_test_predict)

print(err_train, err_test)
# Out:
# 0.14977973568281938 0.2857142857142857

# %%
from sklearn.model_selection import GridSearchCV
nnb = [1, 3, 5, 10, 15, 20, 25, 35, 45, 55]
knn = KNeighborsClassifier()
grid = GridSearchCV(knn, param_grid = {'n_neighbors': nnb}, cv=10)
grid.fit(X_train, y_train.astype('int'))

best_cv_err = 1 - grid.best_score_
best_n_neighbors = grid.best_estimator_.n_neighbors
print(best_cv_err, best_n_neighbors)
# Out:
# D:\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:657: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=10.
#   % (min_groups, self.n_splits)), Warning)
# 0.20264317180616742 5
# D:\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)

# %%
knn = KNeighborsClassifier(n_neighbors = best_n_neighbors).fit(X_train, y_train.astype('int'))

err_train = np.mean(y_train.astype('int') != knn.predict(X_train))
err_test  = np.mean(y_test.astype('int')  != knn.predict(X_test))

print(err_train, err_test)
# Out:
# 0.14977973568281938 0.2857142857142857

# %%
from sklearn import ensemble
rf = ensemble.RandomForestClassifier(n_estimators = 1000)
rf.fit(X_train, y_train.astype('int'))

err_train = np.mean(y_train.astype('int') != rf.predict(X_train))
err_test  = np.mean(y_test.astype('int')  != rf.predict(X_test))

print(err_train, err_test)
# Out:
# 0.0 0.1326530612244898

# %%
importances = rf.feature_importances_
indices = np.argsort(importances)[::-1]

print("Feature ranking:")

for f in range(d):
    print("%2d. feature '%5s' (%f)" % (f + 1, feature_names[indices[f]], importances[indices[f]]))
# Out:
# Feature ranking:
#  1. feature 'pred_minus_obs_H_b1' (0.282290)
#  2. feature 'pred_minus_obs_H_b4' (0.067006)
#  3. feature '   b4' (0.060052)
#  4. feature 'class_h ' (0.059287)
#  5. feature 'pred_minus_obs_H_b9' (0.041194)
#  6. feature 'pred_minus_obs_H_b2' (0.035518)
#  7. feature '   b2' (0.033600)
#  8. feature 'pred_minus_obs_H_b3' (0.027046)
#  9. feature '   b9' (0.026465)
# 10. feature '   b7' (0.025695)
# 11. feature 'pred_minus_obs_S_b6' (0.024736)
# 12. feature 'pred_minus_obs_H_b7' (0.023695)
# 13. feature '   b3' (0.023008)
# 14. feature 'pred_minus_obs_H_b5' (0.022535)
# 15. feature 'pred_minus_obs_S_b1' (0.020547)
# 16. feature 'pred_minus_obs_H_b8' (0.020087)
# 17. feature 'pred_minus_obs_H_b6' (0.019552)
# 18. feature 'pred_minus_obs_S_b5' (0.019434)
# 19. feature 'pred_minus_obs_S_b2' (0.019341)
# 20. feature '   b5' (0.018546)
# 21. feature 'pred_minus_obs_S_b4' (0.018341)
# 22. feature 'pred_minus_obs_S_b7' (0.017909)
# 23. feature 'pred_minus_obs_S_b3' (0.017177)
# 24. feature 'pred_minus_obs_S_b8' (0.016947)
# 25. feature '   b6' (0.016359)
# 26. feature 'pred_minus_obs_S_b9' (0.015588)
# 27. feature '   b8' (0.010610)
# 28. feature 'class_d ' (0.008101)
# 29. feature 'class_s ' (0.007827)
# 30. feature 'class_o ' (0.001508)

# %%
np.sum(rf.feature_importances_)
# Out:
# 1.0

# %%
importances = rf.feature_importances_
indices = np.argsort(importances)[::-1]

print("Feature ranking:")

for f in range(d):
    print("%2d. feature '%5s' (%f)" % (f + 1, feature_names[indices[f]], importances[indices[f]]))
# Out:
# Feature ranking:
#  1. feature 'pred_minus_obs_H_b1' (0.282290)
#  2. feature 'pred_minus_obs_H_b4' (0.067006)
#  3. feature '   b4' (0.060052)
#  4. feature 'class_h ' (0.059287)
#  5. feature 'pred_minus_obs_H_b9' (0.041194)
#  6. feature 'pred_minus_obs_H_b2' (0.035518)
#  7. feature '   b2' (0.033600)
#  8. feature 'pred_minus_obs_H_b3' (0.027046)
#  9. feature '   b9' (0.026465)
# 10. feature '   b7' (0.025695)
# 11. feature 'pred_minus_obs_S_b6' (0.024736)
# 12. feature 'pred_minus_obs_H_b7' (0.023695)
# 13. feature '   b3' (0.023008)
# 14. feature 'pred_minus_obs_H_b5' (0.022535)
# 15. feature 'pred_minus_obs_S_b1' (0.020547)
# 16. feature 'pred_minus_obs_H_b8' (0.020087)
# 17. feature 'pred_minus_obs_H_b6' (0.019552)
# 18. feature 'pred_minus_obs_S_b5' (0.019434)
# 19. feature 'pred_minus_obs_S_b2' (0.019341)
# 20. feature '   b5' (0.018546)
# 21. feature 'pred_minus_obs_S_b4' (0.018341)
# 22. feature 'pred_minus_obs_S_b7' (0.017909)
# 23. feature 'pred_minus_obs_S_b3' (0.017177)
# 24. feature 'pred_minus_obs_S_b8' (0.016947)
# 25. feature '   b6' (0.016359)
# 26. feature 'pred_minus_obs_S_b9' (0.015588)
# 27. feature '   b8' (0.010610)
# 28. feature 'class_d ' (0.008101)
# 29. feature 'class_s ' (0.007827)
# 30. feature 'class_o ' (0.001508)

# %%
feature_names[[1,0,1]]
# Out:
# Index(['b3', 'b2', 'b3'], dtype='object')

# %%
d_first = 20
plt.title("Feature importances")
plt.bar(range(d_first), importances[indices[:d_first]], align = 'center', color = 'r')
plt.xticks(range(d_first), feature_names[indices[:d_first]], rotation = 90)
plt.xlim([-1, d_first])
# Out:
# (-1, 20)

# %%
ert = ensemble.ExtraTreesClassifier(n_estimators = 100).fit(X_train, y_train.astype('int'))

err_train = np.mean(y_train.astype('int') != ert.predict(X_train))
err_test  = np.mean(y_test.astype('int')  != ert.predict(X_test))

print(err_train, err_test)
# Out:
# 0.0 0.19387755102040816

# %%
ada = ensemble.AdaBoostClassifier(n_estimators = 1000)
ada.fit(X_train, y_train.astype('int'))

err_train = np.mean(y_train.astype('int') != ada.predict(X_train))
err_test = np.mean(y_test.astype('int') != ada.predict(X_test))

print(err_train, err_test)
# Out:
# 0.15418502202643172 0.22448979591836735

# %%
gbt = ensemble.GradientBoostingClassifier(n_estimators = 1000)
gbt.fit(X_train, y_train.astype('int'))

err_train = np.mean(y_train.astype('int') != gbt.predict(X_train))
err_test = np.mean(y_test.astype('int') != gbt.predict(X_test))

print(err_train, err_test)
# Out:
# 0.0 0.10204081632653061

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2)

# %%
X_train_PCA = pca.fit_transform(X_train)

# %%
plt.plot(X_train_PCA[0], X_train_PCA[1], 'o')
plt.xlabel('x1')
plt.ylabel('x2')
plt.title('Test')
# Out:
# Text(0.5, 1.0, 'Test')

# %%
print(pca.explained_variance_ratio_)
# Out:
# [0.39168317 0.17898548]

# %%
print(pca.singular_values_)
# Out:
# [48.66118379 32.89456278]

# %%
error_values = {}
for i in range(2,27,1):
    pca_train = PCA(n_components=i)

    X_train_PCA = pca_train.fit_transform(X_train)
    X_test_PCA = pca_train.fit_transform(X_test) 
    
    knn = KNeighborsClassifier(n_neighbors = best_n_neighbors).fit(X_train_PCA, y_train.astype('int'))

    err_train = np.mean(y_train.astype('int') != knn.predict(X_train_PCA))
    err_test  = np.mean(y_test.astype('int')  != knn.predict(X_test_PCA))
    error_values[i]=[err_train, err_test]

# %%
X_values = [item for item in error_values.keys()]
Y_values = [item[0] for item in error_values.values()]
Y_values_test = [item[1] for item in error_values.values()]
plt.plot(X_values, Y_values)
plt.plot(X_values, Y_values_test)
plt.xlabel('Number of PCA')
plt.ylabel('Error')
plt.title('Test')
# Out:
# Text(0.5, 1.0, 'Test')

# %%
# Следует выделить, что наименьшая ошибка на тестовой выборке достигается при числе главных компонент = 9 и 10
# Свыше 11 главных компонент ошибка перестает изменяться
print(error_values[9])
print(error_values[10])
# Out:
# [0.15418502202643172, 0.2755102040816326]
# [0.15418502202643172, 0.2755102040816326]

# %%
# В данном случае PCA не позволяет снизить ошибку на тестовой выборке по сравнению с другими методами

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 7)
N_test, _ = X_test.shape
y_train = y_train.astype("int")
y_test = y_test.astype("int")

# %%
from sklearn.neural_network import MLPClassifier

# %%
mlp_model = MLPClassifier(hidden_layer_sizes = (2,), solver = 'lbfgs', 
                          activation = 'logistic', random_state = 42)
mlp_model.fit(X_train, y_train)
# Out:
# MLPClassifier(activation='logistic', alpha=0.0001, batch_size='auto',
#               beta_1=0.9, beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(2,), learning_rate='constant',
#               learning_rate_init=0.001, max_iter=200, momentum=0.9,
#               n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#               random_state=42, shuffle=True, solver='lbfgs', tol=0.0001,
#               validation_fraction=0.1, verbose=False, warm_start=False)

# %%
y_train_pred = mlp_model.predict(X_train)
y_test_pred = mlp_model.predict(X_test)

# %%
# Ошибка на тестовой и обучающей выборке
print(np.mean(y_train != y_train_pred), np.mean(y_test != y_test_pred))
# Out:
# 0.03686635944700461 0.1111111111111111

# %%
print(mlp_model.score(X_train, y_train), mlp_model.score(X_test, y_test))
# Out:
# 0.9631336405529954 0.8888888888888888

# %%
print(1 - mlp_model.score(X_test, y_test))
# Out:
# 0.11111111111111116

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test_pred, y_test))
# Out:
# [[ 0  0  0  0  0]
#  [ 3 12  6  0  0]
#  [ 0  0 73  1  0]
#  [ 0  0  1 11  1]
#  [ 0  0  0  0  0]]

# %%
M = confusion_matrix(y_test_pred, y_test)
M = np.sqrt(M)
plt.imshow(M, interpolation = 'nearest')
plt.set_cmap('binary')
plt.xticks(range(5))
plt.yticks(range(5))
plt.xlabel("true label")
plt.ylabel("predicted label")
plt.colorbar()
pass

# %%
alpha_arr = np.logspace(-3, 2, 21)
test_err = []
train_err = []
for alpha in alpha_arr:
    mlp_model = MLPClassifier(alpha = alpha, hidden_layer_sizes = (2,), 
                              solver = 'lbfgs', activation = 'logistic', random_state = 42)
    mlp_model.fit(X_train, y_train)

    y_train_pred = mlp_model.predict(X_train)
    y_test_pred = mlp_model.predict(X_test)
    train_err.append(np.mean(y_train != y_train_pred))
    test_err.append(np.mean(y_test != y_test_pred))

# %%
plt.semilogx(alpha_arr, train_err, 'b-o', label = 'train')
plt.semilogx(alpha_arr, test_err, 'r-o', label = 'test')
plt.xlim([np.max(alpha_arr), np.min(alpha_arr)])
plt.title('Error vs. alpha')
plt.xlabel('alpha')
plt.ylabel('error')
plt.legend()
pass

# %%
min_train_err = np.min(train_err)
min_test_err = np.min(test_err)
print(min_train_err, min_test_err)

# При alpha > 4 наблюдается недообучение алгоритма, величина ошибки на обучающей выборке оказывается выше 
# ошибки на тестовой выборке
# Out:
# 0.03686635944700461 0.08333333333333333

# %%
alpha_opt = alpha_arr[test_err == min_test_err]
print(alpha_opt)
# Out:
# [0.00562341 0.56234133 1.        ]

# %%
alpha_opt = alpha_opt[0]

# %%
mlp_model = MLPClassifier(alpha = alpha_opt, hidden_layer_sizes = (2,),
                          solver = 'lbfgs', activation = 'logistic', random_state = 42)
mlp_model.fit(X_train, y_train)

y_train_pred = mlp_model.predict(X_train)
y_test_pred = mlp_model.predict(X_test)
print(np.mean(y_train != y_train_pred))
print(np.mean(y_test != y_test_pred))
# Out:
# 0.03686635944700461
# 0.08333333333333333

# %%
layer_sizes_arr = np.arange(2, 40, 1)
test_err = []
train_err = []
for layer_sizes in layer_sizes_arr:
    mlp_model = MLPClassifier(alpha = alpha_opt, hidden_layer_sizes = (layer_sizes,), 
                              solver = 'lbfgs', activation = 'logistic', random_state = 42)
    mlp_model.fit(X_train, y_train)

    y_train_pred = mlp_model.predict(X_train)
    y_test_pred = mlp_model.predict(X_test)
    train_err.append(np.mean(y_train != y_train_pred))
    test_err.append(np.mean(y_test != y_test_pred))

# %%
plt.plot(layer_sizes_arr, train_err, 'b-o', label = 'train')
plt.plot(layer_sizes_arr, test_err, 'r-o', label = 'test')
#plt.xlim([np.max(layer_sizes_arr), np.min(layer_sizes_arr)])
plt.title('Error vs. number of neurons')
plt.xlabel('Number of neurons')
plt.ylabel('error')
plt.legend()
pass

# %%
min_train_err = np.min(train_err)
min_test_err = np.min(test_err)
print(min_train_err, min_test_err)

layer_opt = layer_sizes_arr[test_err == min_test_err]
print("Оптимальное число нейронов:{}".format(layer_opt))
# С числа нейронов, равного 3, наблюдается периодическое переобучение алгоритма.
# При числе нейронов, равном 1, наблюдается недообучение алгоритма, так как модель получается слишком простой.
# Out:
# 0.0 0.06481481481481481
# Оптимальное число нейронов:[30]

# %%
from sklearn.ensemble import RandomForestClassifier
RFC = RandomForestClassifier(n_estimators=100, random_state=42, oob_score=True)
RFC.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=True, random_state=42, verbose=0,
#                        warm_start=False)

# %%
y_train_pred = RFC.predict(X_train)
y_test_pred = RFC.predict(X_test)

# %%
print(np.mean(y_train != y_train_pred), np.mean(y_test != y_test_pred))
# Out:
# 0.0 0.09259259259259259

# %%
est_arr = np.arange(16, 101, 5)
test_err = []
train_err = []
oob_err = []
RFC = RandomForestClassifier(warm_start=True, n_estimators=1, random_state=42, oob_score=True)
for est in est_arr:
    RFC.set_params(n_estimators=est)
    RFC.fit(X_train, y_train)

    y_train_pred = RFC.predict(X_train)
    y_test_pred = RFC.predict(X_test)
    
    train_err.append(np.mean(y_train != y_train_pred))
    test_err.append(np.mean(y_test != y_test_pred))
    oob_err.append(1 - RFC.oob_score_)

# %%
plt.plot(est_arr, train_err, 'b-o', label = 'train')
plt.plot(est_arr, test_err, 'r-o', label = 'test')
plt.plot(est_arr, oob_err, 'g-o', label = 'oob')
#plt.xlim([np.max(layer_sizes_arr), np.min(layer_sizes_arr)])
plt.title('Error vs. number of trees')
plt.xlabel('Number of trees')
plt.ylabel('error')
plt.legend()
pass

# %%
min_train_err = np.min(train_err)
min_test_err = np.min(test_err)
min_oob_error = np.min(oob_err)
print(min_train_err, min_test_err, min_oob_error)

# Оптимальное количество деревьев:
est_opt = est_arr[test_err == min_test_err]
print("Оптимальное число деревьев:{}".format(est_opt))

# Минимум oob ошибки достигается при количестве деревьев:
oob_opt = est_arr[oob_err == min_oob_error]
print("Минимум oob ошибки при числе деревьев:{}".format(oob_opt))
# Out:
# 0.0 0.08333333333333333 0.15207373271889402
# Оптимальное число деревьев:[46 51 56 61 66]
# Минимум oob ошибки при числе деревьев:[26 51 96]

# %%
from sklearn.ensemble import GradientBoostingClassifier
GBC = GradientBoostingClassifier(n_estimators=100, random_state=42)
GBC.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#                            learning_rate=0.1, loss='deviance', max_depth=3,
#                            max_features=None, max_leaf_nodes=None,
#                            min_impurity_decrease=0.0, min_impurity_split=None,
#                            min_samples_leaf=1, min_samples_split=2,
#                            min_weight_fraction_leaf=0.0, n_estimators=100,
#                            n_iter_no_change=None, presort='auto',
#                            random_state=42, subsample=1.0, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)

# %%
y_train_pred = GBC.predict(X_train)
y_test_pred = GBC.predict(X_test)

# %%
print(np.mean(y_train != y_train_pred), np.mean(y_test != y_test_pred))
# Out:
# 0.0 0.08333333333333333

# %%
est_arr = np.arange(16, 101, 5)
test_err = []
train_err = []
GBC = GradientBoostingClassifier(n_estimators=1, random_state=42)
for est in est_arr:
    GBC.set_params(n_estimators=est)
    GBC.fit(X_train, y_train)

    y_train_pred = GBC.predict(X_train)
    y_test_pred = GBC.predict(X_test)
    train_err.append(np.mean(y_train != y_train_pred))
    test_err.append(np.mean(y_test != y_test_pred))

# %%
plt.plot(est_arr, train_err, 'b-o', label = 'train')
plt.plot(est_arr, test_err, 'r-o', label = 'test')
#plt.xlim([np.max(layer_sizes_arr), np.min(layer_sizes_arr)])
plt.title('Error vs. number of trees')
plt.xlabel('Number of trees')
plt.ylabel('error')
plt.legend()
pass

# %%
min_train_err = np.min(train_err)
min_test_err = np.min(test_err)
print(min_train_err, min_test_err)


# Оптимальное количество деревьев:
est_opt = est_arr[test_err == min_test_err]
print("Оптимальное число деревьев:{}".format(est_opt))

# в дальнейшем при усложнении модели (c 56 деревьев) ошибка на тестовой выборке возрастает.
# Out:
# 0.0 0.05555555555555555
# Оптимальное число деревьев:[51 56]

# %%
# Общие выводы:

# В рамках лабораторных работ были опробованы различные функции библиотек numpy, pandas, matplotlib,
# различные алгоритмы обучения (метод K-ближайших соседей, метод главных компонент и другие)

# На выбранном датасете лучше всего себя проявил Gradient Boosting с числом деревьев = 51-56
# так как данный метод позволяет улучшать предсказания, обучаясь на ошибках предыдущих деревьев решений,
# благодаря этому улучшая точность предсказаний по сравнению с другими методами обучения.
# При большем числе деревьев возникает переусложнение модели, из-за чего ошибка на тестовой выборке увеличивается
# (при 1000 деревьев ошибка возрастает с 0.055 до 0.102).
